# %% [markdown]
# ## read_csv (默认, 是分隔符)

# %%
import pandas as pd
df=pd.read_csv('data/studentscores.csv')
df
# Out:
#     hours  scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# ## read_table(自己制定分隔符)

# %%
pd_1=pd.read_table('data/studentscores.csv',sep=',')
pd_1
# Out:
#     hours  scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
pf_3=pd.read_csv('data/untitled.csv')
pf_3
# Out:
#    1  2  3  4  hello
# 0  5  6  7  8  world

# %%
# 改pf_3的表头
name=['zero','first','second','third','word']
pd.read_csv('data/untitled.csv',names=name)
# Out:
#    zero  first  second  third   word
# 0     1      2       3      4  hello
# 1     5      6       7      8  world

# %%
# word作为索引
pd.read_csv('data/untitled.csv',names=name,index_col='word')
# Out:
#        zero  first  second  third
# word
# hello     1      2       3      4
# world     5      6       7      8

# %%
# !type data\csv_mindex.csv  
# type 直接查看文件内容
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
frame=pd.read_csv('data/csv_mindex.csv',index_col=['key1','key2'])
frame
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
list(open('data/ex3.txt'))

#有多个分隔符
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491']

# %%
frame_1=pd.read_table('data/ex3.txt',sep='\s+') 
# s+表示多个空格
frame_1
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %% [markdown]
# ### 处理缺失值
# 后续通过实例来深入学习

# %% [markdown]
# ### 分块读入文本文件
# chunk 块

# %%
import pandas as pd
chunker=pd.read_csv('D:/python学习/python_2/pydata-book-2--3rd-edition/examples/ex6.csv',chunksize=1000)
chunker
# 返回值是一个可迭代的东西

# %%
for result in chunker:
    print(result)
    
# 每1000个数据进行一次划分
# Out:
#           one       two     three      four key
# 0    0.467976 -0.038649 -0.295344 -1.824726   L
# 1   -0.358893  1.404453  0.704965 -0.200638   B
# 2   -0.501840  0.659254 -0.421691 -0.057688   G
# 3    0.204886  1.074134  1.388361 -0.982404   R
# 4    0.354628 -0.133116  0.283763 -0.837063   Q
# ..        ...       ...       ...       ...  ..
# 995  2.311896 -0.417070 -1.409599 -0.515821   M
# 996 -0.479893 -0.650419  0.745152 -0.646038   H
# 997  0.523331  0.787112  0.486066  1.093156   D
# 998 -0.362559  0.598894 -1.843201  0.887292   W
# 999 -0.096376 -1.012999 -0.657431 -0.573315   K
#
# [1000 rows x 5 columns]
#            one       two     three      four key
# 1000  0.467976 -0.038649 -0.295344 -1.824726   T
# 1001 -0.358893  1.404453  0.704965 -0.200638   J
# 1002 -0.501840  0.659254 -0.421691 -0.057688   R
# 1003  0.204886  1.074134  1.388361 -0.982404   S
# 1004  0.354628 -0.133116  0.283763 -0.837063   B
# ...        ...       ...       ...       ...  ..
# ...

# %%
chunker=pd.read_csv('D:/python学习/python_2/pydata-book-2--3rd-edition/examples/ex6.csv',chunksize=1000)
for result in chunker:
    print(result['key'].value_counts())
    
# 分组显示
# Out:
# S    48
# O    44
# F    40
# H    39
# Q    39
# J    39
# G    38
# R    38
# X    37
# I    37
# V    35
# U    33
# D    32
# E    32
# W    31
# L    31
# K    31
# A    30
# M    29
# Y    28
# T    27
# N    27
# C    27
# Z    26
# B    25
# P    25
# 7    17
# 6    17
# 4    17
# 3    15
# 8    13
# 1    13
# 2    11
# 9    11
# 0     9
# 5     9
# Name: key, dtype: int64
# O    48
# L    44
# X    40
# I    39
# R    38
# F    37
# Q    35
# D    34
# V    33
# K    33
# E    32
# H    31
# J    31
# T    31
# A    31
# U    30
# N    30
# Z    30
# M    28
# S    27
# Y    27
# G    26
# P    26
# W    25
# B    24
# C    23
# 5    20
# 0    19
# 9    19
# 8    19
# 4    18
# 1    16
# 3    16
# 2    14
# 6    14
# 7    12
# Name: key, dtype: int64
# A    40
# O    40
# X    39
# E    39
# M    38
# H    37
# T    36
# G    36
# K    34
# L    34
# U    33
# F    32
# B    32
# N    31
# V    31
# S    30
# P    30
# Z    29
# W    29
# J    29
# D    28
# R    28
# ...

# %% [markdown]
# ### 将数据写入文本格式

# %%
# 生成时间数据 从2022.10.1开始 期限为7天
datas=pd.date_range('10/3/2022',periods=7)
datas
# Out:
# DatetimeIndex(['2022-10-03', '2022-10-04', '2022-10-05', '2022-10-06',
#                '2022-10-07', '2022-10-08', '2022-10-09'],
#               dtype='datetime64[ns]', freq='D')

# %%
# 生成7个数字，索引为刚刚的日期

ta=pd.DataFrame(range(7),index=datas)
ta
# Out:
#             0
# 2022-10-03  0
# 2022-10-04  1
# 2022-10-05  2
# 2022-10-06  3
# 2022-10-07  4
# 2022-10-08  5
# 2022-10-09  6

# %% [markdown]
# ### 处理分隔格式

# %%
# 一些read_csv 处理不了的值
# !type data\examples\ex7.csv
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
# 读取文件的思想：1.用csv去读文件
import csv
f=open('data/examples/ex7.csv')
reader=csv.reader(f)
reader
# 读出来的内容 是一个可迭代对象

# %% [markdown]
# ##### 1.尝试用for循环读取内容

# %%
for result in reader:
    print(result)
print(type(result))
# 是一个类list，但不是真正的list
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']
# <class 'list'>

# %% [markdown]
# ##### 2.读取的内容变成list

# %%
import csv
f=open('data/examples/ex7.csv')
reader_1=list(csv.reader(f))
reader_1
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3']]

# %% [markdown]
# ##### 3.读取内容变成字典

# %%
# 形式 a:[],b:[]
import csv
f=open('data/examples/ex7.csv')
reader_1=tuple(csv.reader(f))
data_dict={h:v for h,v in zip(reader_1[0],reader_1[1:])}
data_dict
# Out:
# {'a': ['1', '2', '3'], 'b': ['1', '2', '3']}

# %% [markdown]
# ### json文件转换

# %% [markdown]
# #### json → python

# %%
# 假设有一个obj.json文件(里面存储str文本)

import json
aspython=json.loads(obj)
aspython
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12396/2708185008.py in <module>
#       2
#       3 import json
# ----> 4 aspython=json.loads(obj)
#       5 aspython
#
# NameError: name 'obj' is not defined

# %% [markdown]
#  #### python→json

# %%
asjson=json.dumps(aspython)
asjson

# %% [markdown]
# ### pd.read_json 可以直接把json数据集按照指定的次序转换成Series或者DataFrame

# %%
# !type data\examples\example.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
#  {"a": 4, "b": 5, "c": 6},
#  {"a": 7, "b": 8, "c": 9}]

# %%
import pandas as pd
import json
data=pd.read_json('data/examples/example.json')
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# Series 或DataFrame 文件再转换成json文件
import pandas as pd
import json
data=pd.read_json('data/examples/example.json')
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}

# %% [markdown]
# ### 网络抓取

# %% [markdown]
# ##### 美国FDIC政府机构下载的显示银行倒闭数据的HTML文件

# %%
# !type data\examples\fdic_failed_bank_list.html
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0057)https://www.fdic.gov/bank/individual/failed/banklist.html -->
# <html lang="en-US"><!-- Content language is American English. --><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <title>FDIC: Failed Bank List</title>
# <!-- Meta Tags -->
# <meta charset="UTF-8">
# <!-- Unicode character encoding -->
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <!-- Turns off IE Compatiblity Mode -->
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
# <!-- Makes it so phones don't auto zoom out. -->
# <meta name="author" content="DRR">
# <meta http-equiv="keywords" name="keywords" content="banks, financial institutions, failed, failure, closing, deposits, depositors, banking services, assuming institution, acquiring institution, claims">
# <!-- CSS -->
# <link rel="stylesheet" type="text/css" href="./fdic_failed_bank_list_files/responsive.css">
# ...

# %% [markdown]
# #### pd.read_html('address') 默认情况下分会DataFrame列表

# %%
import pandas as pd
tables=pd.read_html('data/examples/fdic_failed_bank_list.html')
# tables
failures=tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
# 很重要的一个命令
# 已经排序过了
close_times=pd.to_datetime(failures['Closing Date']) 
close_times
# Out:
# 0     2016-09-23
# 1     2016-08-19
# 2     2016-05-06
# 3     2016-04-29
# 4     2016-03-11
#          ...
# 542   2001-07-27
# 543   2001-05-03
# 544   2001-02-02
# 545   2000-12-14
# 546   2000-10-13
# Name: Closing Date, Length: 547, dtype: datetime64[ns]

# %% [markdown]
# ### 二进制格式

# %%
import csv
frame=pd.read_csv('data/examples/ex1.csv')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# 以二进制形式保存
frame.to_pickle('data/examples/frame_pickle')

# %%
# 读取二进制文件
pd.read_pickle('data/examples/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# ### 读excel文件

# %%
frame=pd.read_excel('data/examples/ex1.xlsx')

frame
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %% [markdown]
# ### 与网站进行交互

# %%
import requests
url='https://api.githup.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)
resp
# 返回的是一个json对象
# Out:
# <Response [200]>

# %% [markdown]
# ##### 数据显示有问题

# %% [markdown]
# ### 与数据库进行交互(之后进行学习)
#     1.数据库连接
#     2.执行sql语句
#     3.提交
#     4.关闭连接
